# %% [markdown]
# # MLB Salary Cap Analysis - Case Study 3
#
# ## Research Question
# With MLB owners proposing a \\$245.3M cap and \\$171.2M floor for the 2027 season,
# which teams face the greatest structural pressure on either end — and what does
# 20 years of World Series history suggest about what's actually at stake competitively?
#
# ## Structure
# 1. Cap Pressure - teams currently above \$245.3M
# 2. Floor Pressure - teams currently under \$171.2M
# 3. World Series History - payroll of champions over last 20 years
# 4. Closing Thesis - asymmetric pressure analysis

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd        # tabular data — loading, filtering, merging, transforming
import numpy as np         # numerical operations and array math
import matplotlib.pyplot as plt  # base visualization library
import seaborn as sns      # statistical visualizations, cleaner defaults than raw matplotlib
import pybaseball as pb    # pulls data from Baseball Reference, FanGraphs, Statcast
import requests

# %% [markdown]
# ## Section 1 — Cap Pressure
#
# Identifying which MLB teams currently exceed the proposed \$245.3M salary cap,
# and quantifying how much they would need to shed to comply.

# %% [markdown]
# ### Data Source — 2026 Team Payrolls
#
# Current team payroll data is sourced from Spotrac, which tracks real-time
# MLB salary commitments. Since no direct download is available, we scrape
# the data programmatically using pandas' `read_html()` function. We're using
# 2026 figures as the most relevant proxy for evaluating pressure against the
# proposed 2027 salary cap and floor thresholds.

# %%
# url = 'https://www.spotrac.com/mlb/payroll/_/year/2026'
# tables = pd.read_html(url)
# print(len(tables))

# headers = {'User-Agent': 'Mozilla/5.0'}
# response = requests.get(url, headers=headers)
# tables = pd.read_html(response.text)
# print(len(tables))

# %% [markdown]
# ### A Note on Data Collection
#
# Initial efforts to scrape 2026 team payroll figures directly from Spotrac
# were unsuccessful due to the site's use of JavaScript to render its data
# tables. Attempts using `requests` and `pd.read_html()` retrieved only
# static HTML — the payroll table itself is loaded dynamically and requires
# a browser to execute. A full scraping solution would utilize Python's
# `Selenium` package to control a headless browser and capture the rendered
# output. For simplicity, 2026 payroll figures were manually collected from
# Spotrac and loaded via CSV.

# %%
payroll_df = pd.read_csv('payrolls_2026_cube.csv')
payroll_df.head()
# Out:
#   Team Total Payroll
# 0  PHI   313,201,706
# 1  TOR   309,484,438
# 2  NYY   337,140,544
# 3  NYM   381,002,101
# 4  ATL   246,555,515

# %%
payroll_df.dtypes
# Out:
# Team             str
# Total Payroll    str
# dtype: object

# %%
payroll_df['Total Payroll'] = payroll_df['Total Payroll'].str.replace(',','').astype(int)

# %%
print(payroll_df.head())
print(payroll_df['Total Payroll'].sum())
# Out:
#   Team  Total Payroll
# 0  PHI      313201706
# 1  TOR      309484438
# 2  NYY      337140544
# 3  NYM      381002101
# 4  ATL      246555515
# 6130926880

# %%
CAP = 245_300_000 # underscores are just visual
over_cap = payroll_df[payroll_df['Total Payroll'] > CAP].copy()
print(over_cap)
# Out:
#    Team  Total Payroll
# 0   PHI      313201706
# 1   TOR      309484438
# 2   NYY      337140544
# 3   NYM      381002101
# 4   ATL      246555515
# 5   LAD      415212461
# 8   CHC      248474822
# 14  BOS      266101898
# 16   SD      255992138

# %%
over_cap['Over Cap'] = over_cap['Total Payroll'] - CAP
over_cap['Gap Pct'] = over_cap['Over Cap'] / over_cap['Total Payroll']
over_cap.sort_values('Over Cap', ascending=False)
# Out:
#    Team  Total Payroll   Over Cap   Gap Pct
# 5   LAD      415212461  169912461  0.409218
# 3   NYM      381002101  135702101  0.356172
# 2   NYY      337140544   91840544  0.272410
# 0   PHI      313201706   67901706  0.216799
# 1   TOR      309484438   64184438  0.207391
# 14  BOS      266101898   20801898  0.078173
# 16   SD      255992138   10692138  0.041767
# 8   CHC      248474822    3174822  0.012777
# 4   ATL      246555515    1255515  0.005092

# %%
top2 = over_cap.loc[over_cap['Team'].isin(['LAD', 'NYM']), 'Over Cap'].sum()
print(f"LAD + NYM overage: {top2:,} ({top2 / over_cap['Over Cap'].sum():.1%} of total)")
# Out:
# LAD + NYM overage: 305,614,562 (54.0% of total)

# %% [markdown]
# This is looking at the teams that would go over the cap limit. Taking the difference ("Over Cap"), leaves us with five teams over /$60 million that they would need to shed. That's likely a taller task than the bottom four (BOS, SD, CHC, ATL) which would likely need to remove bloated middle-relief contracts from their payroll.

# %%
FLOOR = 171_200_000
under_floor = payroll_df[payroll_df['Total Payroll'] < FLOOR].copy()
under_floor.count()
# Out:
# Team             12
# Total Payroll    12
# dtype: int64

# %%
under_floor['Under Floor'] = FLOOR - under_floor['Total Payroll']
under_floor['Gap Pct'] = under_floor['Under Floor'] / under_floor['Total Payroll']
under_floor.sort_values('Under Floor', ascending=False)
# Out:
#    Team  Total Payroll  Under Floor   Gap Pct
# 26  MIA       81941404     89258596  1.089298
# 23  CLE       87827999     83372001  0.949264
# 21   TB      108325756     62874244  0.580418
# 27  CHW      108379653     62820347  0.579632
# 28  STL      111559321     59640679  0.534610
# 29  WSH      114624471     56575529  0.493573
# 25  MIN      123266143     47933857  0.388865
# 22  COL      131609949     39590051  0.300814
# 17  PIT      134501207     36698793  0.272851
# 24  ATH      136029542     35170458  0.258550
# 18  MIL      139000376     32199624  0.231651
# 20  CIN      148667572     22532428  0.151562

# %% [markdown]
# A note on the data: we're using 2026 salary totals to evaluate teams against the proposed 2027 cap and floor. These aren't 2027 commitments — payrolls shift year to year as contracts expire and teams restructure — so this is a best-available proxy rather than a precise forecast. It's directionally sound for identifying which teams face structural pressure, but actual 2027 figures will move.

# %%
print(f"Total payroll over proposed cap: {over_cap['Over Cap'].sum():,}")
print(f"Total payroll under proposed floor: {under_floor['Under Floor'].sum():,}")
# Out:
# Total payroll over proposed cap: 565,465,623
# Total payroll under proposed floor: 628,666,607

# %%
# Cap teams = positive distance from the line
cap_plot = over_cap[['Team', 'Over Cap']].copy()
cap_plot = cap_plot.rename(columns={'Over Cap': 'Distance'})
cap_plot['Side'] = 'Over Cap'

floor_plot = under_floor[['Team', 'Under Floor']].copy()
floor_plot = floor_plot.rename(columns={'Under Floor': 'Distance'})
floor_plot['Distance'] = -floor_plot['Distance']
floor_plot['Side'] = 'Under Floor'

#combine both sides into one dataframe
combined = pd.concat([cap_plot, floor_plot])
combined = combined.sort_values('Distance', ascending=False)

#Plot
fig, ax = plt.subplots(figsize=(10, 9))
colors = combined['Side'].map({'Over Cap': '#c0392b', 'Under Floor': '#2980b9'})
ax.barh(combined['Team'], combined['Distance']/1_000_000, color=colors)

ax.axvline(0, color='black', linewidth=0.8) #threshould line at 0
ax.set_xlabel('Distance from Threshold (Millions of $)')
ax.set_title('Structural Pressure Under Proposed 2027 Cap/Floor\nOver Cap (red) vs. Under Floor (blue)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Reading the Chart
#
# The figure above shows the teams that fall under the proposed floor — **12 teams
# totaling \$628.7M to make up** — and over the proposed cap — **9 teams totaling
# \$565.5M to shed** — with the remaining 9 teams already sitting within the
# proposed bounds. This difference is near 1:1 in raw dollars, contrary to the
# initial hypothesis of a disproportionate burden being placed on teams under
# the floor.
#
# ### Findings
#
# - **The cap burden is concentrated.** Nine teams sit over the cap, but the
#   burden is far from evenly distributed. Two of them — the New York Mets (NYM)
#   and Los Angeles Dodgers (LAD) — account for **54% of the total payroll
#   overage**. Just below them, the Yankees (NYY), Phillies (PHI), and Blue Jays
#   (TOR) form a more manageable middle tier, ranging from roughly \$64–92M over.
#   At the bottom, the Atlanta Braves (ATL), Chicago Cubs (CHC), San Diego Padres
#   (SD), and Boston Red Sox (BOS) represent a combined \$35.9M — a fraction of
#   NYM and LAD's combined \$305.6M. ATL and CHC, in fact, sit within a single
#   contract's value of the cap line — and a low-tier contract at that.
#
# - **The floor burden is broad and proportionally heavier.** Twelve teams fall
#   below the proposed floor, with gaps ranging from **15–109% of existing
#   payroll**. Half face the challenge of increasing payroll by 49% or more;
#   Miami, in particular, would need to *exceed its entire current payroll* to
#   comply — functionally changing the team's strategic philosophy.
#
# - **The burdens differ in kind.** The proposed cap targets a handful of
#   franchises; the floor impacts a wider range of teams more proportionally.
#   Teams over the cap must shed chosen commitments (concentrated,
#   transactional), while teams under the floor must abandon a roster-building
#   strategy altogether (broad, structural).
#
# But does spending at these levels translate to on-field success? The next
# section examines the World Series participants (pennant winners) of the last
# 21 seasons (2005–2025), indexing each team's payroll against its own season's
# league average, with the proposed 2027 cap and floor converted to the same
# scale via a projected 2027 league average.

# %%
# Import the World Series contenders from 2025-2025
# Pulled data from https://www.thebaseballcube.com/content/payroll/#google_vignette
world_series_df = pd.read_csv('2005-2025-ws-payroll.csv')
world_series_df.head()
# Out:
#    year champion contender champion-payroll contender-payroll  \
# 0  2005      CHW       HOU       75,228,000        76,779,022
# 1  2006      STL       DET       88,891,371        82,612,866
# 2  2007      BOS       COL      143,026,214        54,424,000
# 3  2008      PHI        TB       98,269,880        43,820,597
# 4  2009      NYY       PHI      201,449,289       113,004,048
#
#   league-total-payroll
# 0        2,191,886,898
# 1        2,326,706,685
# 2        2,476,688,987
# 3        2,686,433,458
# 4        2,655,395,194

# %%
world_series_df['champion-payroll'] = world_series_df['champion-payroll'].str.replace(',','').astype(int)
world_series_df['contender-payroll'] = world_series_df['contender-payroll'].str.replace(',','').astype(int)
world_series_df['league-total-payroll'] = world_series_df['league-total-payroll'].str.replace(',','').astype(int)

world_series_df.dtypes
# Out:
# year                    int64
# champion                  str
# contender                 str
# champion-payroll        int64
# contender-payroll       int64
# league-total-payroll    int64
# dtype: object

# %%
champions = world_series_df[['year','champion','champion-payroll','league-total-payroll']].copy()
champions = champions.rename(columns={'champion':'team','champion-payroll':'payroll'})
champions['Result'] = 'Champion'

contenders = world_series_df[['year','contender','contender-payroll','league-total-payroll']].copy()
contenders = contenders.rename(columns={'contender':'team','contender-payroll':'payroll'})
contenders['Result'] = 'Contender'

world_series_plot = pd.concat([champions,contenders])
world_series_plot['league_avg'] = world_series_plot['league-total-payroll'] / 30
world_series_plot['payroll_index'] = world_series_plot['payroll'] / world_series_plot['league_avg']

# 2026 opening day league total payroll (thebaseballcube.com, retrieved July 2026).
# Kept as a constant rather than a row in the WS csv: that file's grain is one World Series per row, and 2026 has no World Series yet.
# Note: stevetheump.com's 2026 total sums ~5.5% lower despite the same stated opening-day definition; the Cube figure is used for consistency with the
# 2005-2025 league-total series, which is Cube-sourced.
league_total_2026 = 6_130_926_880
league_avg_2026 = league_total_2026 / 30

# Long-run growth rate (2005 -> 2026 CAGR). We deliberately do NOT project
# forward using the single-year 2025->2026 jump (~20%), which is an outlier.
league_avg_2005 = world_series_plot.loc[world_series_plot['year'] == 2005, 'league_avg'].iloc[0]
cagr = (league_avg_2026 / league_avg_2005) ** (1/21)

# 2027 projection: one year forward from the 2026 actual at the long-run rate.
league_avg_2027_proj = league_avg_2026 * cagr

proposed_cap_2027 = 245_300_000 / league_avg_2027_proj
proposed_floor_2027 = 171_200_000 / league_avg_2027_proj


fig, ax = plt.subplots(figsize=(12, 7))
champ = world_series_plot[world_series_plot['Result'] == 'Champion']
cont  = world_series_plot[world_series_plot['Result'] == 'Contender']

ax.scatter(champ['year'], champ['payroll_index'], color='#27ae60', alpha=0.7, label='Champion')
ax.scatter(cont['year'],  cont['payroll_index'],  color='#2980b9', alpha=0.7, label='Contender')


ax.axhline(proposed_cap_2027, color='red', linewidth=0.8, linestyle='--', label='Proposed 2027 Cap')
ax.axhline(proposed_floor_2027, color='blue', linewidth=0.8, linestyle='--', label='Proposed 2027 Floor')
ax.set_xticks(world_series_plot['year'].unique())
ax.legend()
ax.set_xlabel('Year')
ax.set_ylabel('Payroll Index (Team Payroll / League Average)')
plt.tight_layout()
plt.show()

# %%
print(f"2026 league avg: ${league_avg_2026/1e6:.1f}M")
print(f"CAGR 2005-2026: {(cagr-1)*100:.2f}%")
print(f"2027 projected avg: ${league_avg_2027_proj/1e6:.1f}M")
print(f"Cap index: {245_300_000/league_avg_2027_proj:.2f}  Floor index: {171_200_000/league_avg_2027_proj:.2f}")
# Out:
# 2026 league avg: $204.4M
# CAGR 2005-2026: 5.02%
# 2027 projected avg: $214.6M
# Cap index: 1.14  Floor index: 0.80

# %% [markdown]
# ### Reading the Chart
#
# Each point represents a World Series participant (2005–2025), plotted by
# **payroll index**: team Opening Day payroll ÷ that season's league-average
# payroll. An index of 1.0 is league-average spending; 1.4 means 40% above
# average *for that season*. Because each team is normalized against its own
# era, indexes are comparable across seasons — payroll inflation cancels out
# of the ratio.
#
# The reference lines show the proposed 2027 cap ($245.3M) and floor ($171.2M)
# converted to the same scale, using a projected 2027 league average of ~$214.6M
# (2005–2026 CAGR of 5.02% applied to the 2026 average). This places the cap at
# an index of ~1.14 and the floor at ~0.80.
#
# **Interpretive note:** a historical point above the cap line does *not* mean
# that team would have violated the 2027 cap. It means the team spent at a
# relative level (vs. its own era) that exceeds the cap's relative level (vs.
# projected 2027). The comparison is a hypothetical — "what if a cap at this
# relative position had existed?" Two additional caveats: the proposed cap/floor
# figures appear to derive from CBT-style (AAV) methodology, while payrolls here
# are Opening Day guaranteed-salary snapshots — different accounting frameworks;
# and the 2027 denominator is a projection, not an observed value.
#
# ### Findings
#
# - **No World Series champion falls below the proposed floor.** Winning at the
#   highest level has consistently required at least near-average relative
#   spending.
# - **Champions cluster above 1.0.** Most winners spent above their era's league
#   average; several (2009 most extreme, at ~2.25×) spent far above it.
# - **The cap line, not the floor, binds this sample.** League-wide (Section 1),
#   floor pressure dominates — 15 teams below vs. 6 above. But this chart is a
#   winners-only sample, and it inverts: many WS participants sit above the
#   cap's relative level, and almost none below the floor. Read together, the
#   proposed system pressures low-payroll teams broadly while compressing the
#   specific spending levels that have historically produced champions.
# - **Concentration appears to be rising.** From roughly 2018 onward, WS
#   participants increasingly occupy the 1.3–2.0 index range, suggesting
#   championship access is consolidating among the league's top relative
#   spenders.
